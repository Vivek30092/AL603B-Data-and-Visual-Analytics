# %% [markdown]
# >>## SMOTE(Synthetic Minority Oversampling Technique)
# it's a technique used in ML to address imbalanced datasets where the minority class has significantly

# %%
from sklearn.datasets import make_classification
